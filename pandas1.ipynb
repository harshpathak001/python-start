# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]], columns=["A","B","C"], index=["A","B"])
df
# Out:
#    A  B  C
# A  1  2  3
# B  4  5  6

# %%
df= pd.DataFrame([[3,4,5],[4,5,6]],columns=["d","f","g"], index=["A","B"])
df
# Out:
#    d  f  g
# A  3  4  5
# B  4  5  6

# %%
df= pd.DataFrame([[1,2,3],[4,5,6]],columns=["A","B","C"], index="A B".split(" "))
df
# Out:
#    A  B  C
# A  1  2  3
# B  4  5  6

# %%
df.shape
# Out:
# (2, 3)

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.values
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
import pandas as pd
data1 ={
    "ID" : [1,2,3],
    "Name": ["Aarav", "Priya","vikram"],
    "Score": [85,90,78]
}
df1=pd.DataFrame(data1, index=["a", "b", "c"])
df1
# Out:
#    ID    Name  Score
# a   1   Aarav     85
# b   2   Priya     90
# c   3  vikram     78

# %%
#tuple we dont modify the values
data4 = [
    (1, "meera",91,16),
    (2,"sanjay",84,17 ),
    (3,"divya",87,18)
    ]
df=pd.DataFrame(data4, columns=["ID","Name","Score","age"], index=["A","B","C"])
df
# Out:
#    ID    Name  Score  age
# A   1   meera     91   16
# B   2  sanjay     84   17
# C   3   divya     87   18

# %%
data7 ={
    "ID" : pd.Series([1,2,3]),
    "Name": pd.Series(["Aarav", "Priya","vikram"]),
    "Score": pd.Series([85,90,78])
}
df7=pd.DataFrame(data7)
df7
# Out:
#    ID    Name  Score
# 0   1   Aarav     85
# 1   2   Priya     90
# 2   3  vikram     78

# %%
import pandas as pd
import numpy as np
lo=pd.DataFrame(np.random.randint(0,10,(5,5)),columns='P1 P2 P3 P4 P5'.split(" "), index= 's1 s2 s3 s4 s5'.split(" "))
lo
# Out:
#     P1  P2  P3  P4  P5
# s1   7   4   1   4   8
# s2   2   6   4   7   1
# s3   8   4   1   3   4
# s4   3   8   4   6   3
# s5   8   3   4   9   3

# %%
import pandas as pd
df=pd.read_csv("/content/sample.csv", encoding="latin1")
df
# Out:
#    c1  c2  c3
# 0  42  88  62
# 1  81  53  89
# 2  37  48  87
# 3  89  53  67
# 4  94  88  60
# 5  13  29  26

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.iloc[0:1,0:1]
# Out:
#    c1
# 0  42

# %%
df.columns
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
df['c1']
# Out:
# 0    42
# 1    81
# 2    37
# 3    89
# 4    94
# 5    13
# Name: c1, dtype: int64

# %%
import pandas as pd
df=pd.read_csv("/content/sample.csv", encoding="latin1",)
df.head()
# Out:
#    c1  c2  c3
# 0  42  88  62
# 1  81  53  89
# 2  37  48  87
# 3  89  53  67
# 4  94  88  60

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.iloc[0:1,0:1]
# Out:
#    c1
# 0  42

# %%
df.iloc[1:3,0:2]
# Out:
#    c1  c2
# 1  81  53
# 2  37  48

# %%
df[['c1','c2']].head()
# Out:
#    c1  c2
# 0  42  88
# 1  81  53
# 2  37  48
# 3  89  53
# 4  94  88

# %%
df[['c1','c2']].head(2)
# Out:
#    c1  c2
# 0  42  88
# 1  81  53

# %%
df[['c1','c2']].tail(2)
# Out:
#    c1  c2
# 4  94  88
# 5  13  29

# %%
import pandas as pd
customers = pd.DataFrame({
    "CustomerID": [1,2,3,4,5],
    "Name": ["Aarav","Priya","vikram","Meera","Sanjay", ],
    "city":["Delhi","Mumbai","Bengalore","Chennai","Hyderabad", ]
})
print(customers)
# Out:
#    CustomerID    Name       city
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  vikram  Bengalore
# 3           4   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders=pd.DataFrame({
    "OrderID":[101,102,103,104,105],
    "CustomerID":[3,4,5,6,7],
    "Product":["Laptop","Phone","Tablet","Camera","Printer"]
})
print(orders)
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           4    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
customers
# Out:
#    CustomerID    Name       city
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  vikram  Bengalore
# 3           4   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           4    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
inner = pd.merge(customers,orders,on="CustomerID",how="inner")
inner
# Out:
#    CustomerID    Name       city  OrderID Product
# 0           3  vikram  Bengalore      101  Laptop
# 1           4   Meera    Chennai      102   Phone
# 2           5  Sanjay  Hyderabad      103  Tablet

# %%
import pandas as pd
customers = pd.DataFrame({
    "CustomerID": [1,2,3,3,5],
    "Name": ["Aarav","Priya","vikram","Meera","Sanjay", ],
    "city":["Delhi","Mumbai","Bengalore","Chennai","Hyderabad", ]
})
print(customers)
# Out:
#    CustomerID    Name       city
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  vikram  Bengalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
k =pd.merge(customers,orders,on="CustomerID",how="inner")
k
# Out:
#    CustomerID    Name       city  OrderID Product
# 0           3  vikram  Bengalore      101  Laptop
# 1           3   Meera    Chennai      101  Laptop
# 2           5  Sanjay  Hyderabad      103  Tablet
